# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
weather_api_key = 'fabf4ae8a8921a048c820eb8d049b681'

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fabf4ae8a8921a048c820eb8d049b681'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_w_des = city_weather["weather"][0]["description"]
        #add city_w_des into append 
        #city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                         "Description":city_w_des})
                          #"Date": city_date})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | palmerston
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | richmond
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | henties bay
# Processing Record 14 of Set 1 | taoudenni
# Processing Record 15 of Set 1 | marzuq
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | teeli
# Processing Record 18 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | new norfolk
# Processing Record 21 of Set 1 | ormara
# Processing Record 22 of Set 1 | makkaveyevo
# Processing Record 23 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 24 of Set 1 | norman wells
# Processing Record 25 of Set 1 | meulaboh
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | walvis bay
# Processing Record 28 of Set 1 | sitka
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | bokspits
# City not found. Skipping...
# Processing Record 31 of Set 1 | bambous virieux
# Processing Record 32 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | biak
# Processing Record 35 of Set 1 | te anau
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | matamoros
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | georgetown
# Processing Record 41 of Set 1 | great falls
# Processing Record 42 of Set 1 | umm bab
# Processing Record 43 of Set 1 | kavieng
# Processing Record 44 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | hervey bay
# Processing Record 47 of Set 1 | victoria
# Processing Record 48 of Set 1 | shimoda
# Processing Record 49 of Set 1 | berlevag
# Processing Record 50 of Set 1 | hithadhoo
# Processing Record 1 of Set 2 | iskateley
# Processing Record 2 of Set 2 | mayumba
# Processing Record 3 of Set 2 | severo-kurilsk
# Processing Record 4 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 2 | san patricio
# Processing Record 6 of Set 2 | jinchang
# Processing Record 7 of Set 2 | sisimiut
# Processing Record 8 of Set 2 | pochutla
# Processing Record 9 of Set 2 | praia
# Processing Record 10 of Set 2 | vanimo
# Processing Record 11 of Set 2 | pointe michel
# Processing Record 12 of Set 2 | rikitea
# Processing Record 13 of Set 2 | chokurdakh
# Processing Record 14 of Set 2 | nyrob
# Processing Record 15 of Set 2 | saskylakh
# Processing Record 16 of Set 2 | ler
# Processing Record 17 of Set 2 | cap malheureux
# Processing Record 18 of Set 2 | inta
# Processing Record 19 of Set 2 | kozhva
# Processing Record 20 of Set 2 | tilichiki
# Processing Record 21 of Set 2 | pali
# Processing Record 22 of Set 2 | abu dhabi
# Processing Record 23 of Set 2 | leshukonskoye
# Processing Record 24 of Set 2 | upernavik
# Processing Record 25 of Set 2 | manokwari
# Processing Record 26 of Set 2 | kahului
# Processing Record 27 of Set 2 | londa
# Processing Record 28 of Set 2 | wanaka
# Processing Record 29 of Set 2 | beringovskiy
# Processing Record 30 of Set 2 | chissamba
# Processing Record 31 of Set 2 | hami
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | talakan
# Processing Record 34 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 2 | atar
# Processing Record 36 of Set 2 | shingu
# Processing Record 37 of Set 2 | yarada
# Processing Record 38 of Set 2 | salalah
# Processing Record 39 of Set 2 | faanui
# Processing Record 40 of Set 2 | lebu
# Processing Record 41 of Set 2 | havre
# Processing Record 42 of Set 2 | gweta
# Processing Record 43 of Set 2 | arraial do cabo
# Processing Record 44 of Set 2 | port elizabeth
# Processing Record 45 of Set 2 | allonnes
# Processing Record 46 of Set 2 | thompson
# Processing Record 47 of Set 2 | praia da vitoria
# Processing Record 48 of Set 2 | sharjah
# Processing Record 49 of Set 2 | chaozhou
# Processing Record 50 of Set 2 | springdale
# Processing Record 1 of Set 3 | yei
# Processing Record 2 of Set 3 | vagur
# Processing Record 3 of Set 3 | asfi
# Processing Record 4 of Set 3 | tessalit
# Processing Record 5 of Set 3 | guerrero negro
# Processing Record 6 of Set 3 | honiara
# Processing Record 7 of Set 3 | chandler
# Processing Record 8 of Set 3 | coihaique
# Processing Record 9 of Set 3 | willowmore
# Processing Record 10 of Set 3 | conway
# Processing Record 11 of Set 3 | champerico
# Processing Record 12 of Set 3 | manono
# Processing Record 13 of Set 3 | bredasdorp
# Processing Record 14 of Set 3 | ixtapa
# Processing Record 15 of Set 3 | nikolskoye
# Processing Record 16 of Set 3 | khuzhir
# Processing Record 17 of Set 3 | banyo
# Processing Record 18 of Set 3 | maues
# Processing Record 19 of Set 3 | hamilton
# Processing Record 20 of Set 3 | cherskiy
# Processing Record 21 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 3 | anchorage
# Processing Record 23 of Set 3 | bethel
# Processing Record 24 of Set 3 | castro
# Processing Record 25 of Set 3 | tuktoyaktuk
# Processing Record 26 of Set 3 | emerald
# Processing Record 27 of Set 3 | dodge city
# Processing Record 28 of Set 3 | inhambane
# Processing Record 29 of Set 3 | glenwood springs
# Processing Record 30 of Set 3 | barrow
# Processing Record 31 of Set 3 | ahipara
# Processing Record 32 of Set 3 | narsaq
# Processing Record 33 of Set 3 | tateyama
# Processing Record 34 of Set 3 | bowen
# Processing Record 35 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 3 | lavrentiya
# Processing Record 37 of Set 3 | vidosi
# Processing Record 38 of Set 3 | codrington
# Processing Record 39 of Set 3 | ozernovskiy
# Processing Record 40 of Set 3 | asau
# Processing Record 41 of Set 3 | croy
# Processing Record 42 of Set 3 | iqaluit
# Processing Record 43 of Set 3 | luderitz
# Processing Record 44 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 3 | pafos
# Processing Record 46 of Set 3 | butaritari
# Processing Record 47 of Set 3 | tura
# Processing Record 48 of Set 3 | taree
# Processing Record 49 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 3 | avera
# Processing Record 1 of Set 4 | dehloran
# Processing Record 2 of Set 4 | gorontalo
# Processing Record 3 of Set 4 | gambela
# Processing Record 4 of Set 4 | lata
# Processing Record 5 of Set 4 | bubaque
# Processing Record 6 of Set 4 | chuy
# Processing Record 7 of Set 4 | camacha
# Processing Record 8 of Set 4 | yellowknife
# Processing Record 9 of Set 4 | gat
# Processing Record 10 of Set 4 | muroto
# Processing Record 11 of Set 4 | samarai
# Processing Record 12 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 4 | mehamn
# Processing Record 14 of Set 4 | kyren
# Processing Record 15 of Set 4 | kokstad
# Processing Record 16 of Set 4 | acajutla
# Processing Record 17 of Set 4 | nchelenge
# Processing Record 18 of Set 4 | lorengau
# Processing Record 19 of Set 4 | katsuura
# Processing Record 20 of Set 4 | khatanga
# Processing Record 21 of Set 4 | altay
# Processing Record 22 of Set 4 | port blair
# Processing Record 23 of Set 4 | pisco
# Processing Record 24 of Set 4 | marawi
# Processing Record 25 of Set 4 | ponta delgada
# Processing Record 26 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 27 of Set 4 | pangnirtung
# Processing Record 28 of Set 4 | parsabad
# Processing Record 29 of Set 4 | grand forks
# Processing Record 30 of Set 4 | upata
# Processing Record 31 of Set 4 | ruidoso
# Processing Record 32 of Set 4 | saint george
# Processing Record 33 of Set 4 | buraydah
# Processing Record 34 of Set 4 | bousso
# Processing Record 35 of Set 4 | barddhaman
# Processing Record 36 of Set 4 | cayenne
# Processing Record 37 of Set 4 | pineville
# Processing Record 38 of Set 4 | saint anthony
# Processing Record 39 of Set 4 | cidreira
# Processing Record 40 of Set 4 | bluff
# Processing Record 41 of Set 4 | mallaig
# Processing Record 42 of Set 4 | provideniya
# Processing Record 43 of Set 4 | hilo
# Processing Record 44 of Set 4 | belle glade
# Processing Record 45 of Set 4 | coquimbo
# Processing Record 46 of Set 4 | slonim
# Processing Record 47 of Set 4 | ulaanbaatar
# Processing Record 48 of Set 4 | komsomolskiy
# Processing Record 49 of Set 4 | isangel
# Processing Record 50 of Set 4 | lompoc
# Processing Record 1 of Set 5 | paragominas
# Processing Record 2 of Set 5 | saint-augustin
# Processing Record 3 of Set 5 | nantucket
# Processing Record 4 of Set 5 | saint-joseph
# Processing Record 5 of Set 5 | yambio
# Processing Record 6 of Set 5 | port lincoln
# Processing Record 7 of Set 5 | clyde river
# Processing Record 8 of Set 5 | port hardy
# Processing Record 9 of Set 5 | saldanha
# Processing Record 10 of Set 5 | ust-tsilma
# Processing Record 11 of Set 5 | bengkulu
# Processing Record 12 of Set 5 | ferrol
# Processing Record 13 of Set 5 | mount pleasant
# Processing Record 14 of Set 5 | tres arroyos
# Processing Record 15 of Set 5 | grants pass
# Processing Record 16 of Set 5 | chornoliztsi
# Processing Record 17 of Set 5 | doha
# Processing Record 18 of Set 5 | lamu
# Processing Record 19 of Set 5 | indramayu
# Processing Record 20 of Set 5 | cururupu
# Processing Record 21 of Set 5 | kaitangata
# Processing Record 22 of Set 5 | three hills
# Processing Record 23 of Set 5 | gondar
# Processing Record 24 of Set 5 | dudinka
# Processing Record 25 of Set 5 | tuatapere
# Processing Record 26 of Set 5 | mahebourg
# Processing Record 27 of Set 5 | bell ville
# Processing Record 28 of Set 5 | byron bay
# Processing Record 29 of Set 5 | kodiak
# Processing Record 30 of Set 5 | fortuna
# Processing Record 31 of Set 5 | imbituba
# Processing Record 32 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 5 | sao simao
# Processing Record 34 of Set 5 | geraldton
# Processing Record 35 of Set 5 | mar del plata
# Processing Record 36 of Set 5 | baruun-urt
# Processing Record 37 of Set 5 | beni suef
# Processing Record 38 of Set 5 | saint-raymond
# Processing Record 39 of Set 5 | raduzhnyy
# Processing Record 40 of Set 5 | dikson
# Processing Record 41 of Set 5 | ayagoz
# Processing Record 42 of Set 5 | bahia honda
# Processing Record 43 of Set 5 | kariba
# Processing Record 44 of Set 5 | kruisfontein
# Processing Record 45 of Set 5 | todos santos
# Processing Record 46 of Set 5 | marquette
# Processing Record 47 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 5 | ulaangom
# Processing Record 49 of Set 5 | morinville
# Processing Record 50 of Set 5 | mount isa
# Processing Record 1 of Set 6 | pitimbu
# Processing Record 2 of Set 6 | las margaritas
# Processing Record 3 of Set 6 | porto real
# Processing Record 4 of Set 6 | westerly
# Processing Record 5 of Set 6 | hokitika
# Processing Record 6 of Set 6 | rincon
# Processing Record 7 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 6 | ancud
# Processing Record 9 of Set 6 | itarema
# Processing Record 10 of Set 6 | san nicolas
# Processing Record 11 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 6 | burewala
# Processing Record 13 of Set 6 | arlit
# Processing Record 14 of Set 6 | duz
# City not found. Skipping...
# Processing Record 15 of Set 6 | independence
# Processing Record 16 of Set 6 | qeshm
# Processing Record 17 of Set 6 | menongue
# Processing Record 18 of Set 6 | asayita
# City not found. Skipping...
# Processing Record 19 of Set 6 | port hedland
# Processing Record 20 of Set 6 | aykhal
# Processing Record 21 of Set 6 | kars
# Processing Record 22 of Set 6 | launceston
# Processing Record 23 of Set 6 | ostrovnoy
# Processing Record 24 of Set 6 | vestmannaeyjar
# Processing Record 25 of Set 6 | chai badan
# Processing Record 26 of Set 6 | yulara
# Processing Record 27 of Set 6 | puerto del rosario
# Processing Record 28 of Set 6 | san cristobal
# Processing Record 29 of Set 6 | fort saint james
# Processing Record 30 of Set 6 | novokruchininskiy
# Processing Record 31 of Set 6 | auki
# Processing Record 32 of Set 6 | hobyo
# Processing Record 33 of Set 6 | uthal
# Processing Record 34 of Set 6 | pevek
# Processing Record 35 of Set 6 | moussoro
# Processing Record 36 of Set 6 | colborne
# Processing Record 37 of Set 6 | beloha
# Processing Record 38 of Set 6 | nemuro
# Processing Record 39 of Set 6 | nimbahera
# Processing Record 40 of Set 6 | labuhan
# Processing Record 41 of Set 6 | luau
# Processing Record 42 of Set 6 | port augusta
# Processing Record 43 of Set 6 | springbok
# Processing Record 44 of Set 6 | singkawang
# Processing Record 45 of Set 6 | killybegs
# Processing Record 46 of Set 6 | eyl
# Processing Record 47 of Set 6 | hearst
# Processing Record 48 of Set 6 | faya
# Processing Record 49 of Set 6 | kurchum
# Processing Record 50 of Set 6 | port shepstone
# Processing Record 1 of Set 7 | besikduzu
# Processing Record 2 of Set 7 | barinas
# Processing Record 3 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 7 | ardea
# Processing Record 5 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 7 | east london
# Processing Record 7 of Set 7 | airai
# Processing Record 8 of Set 7 | yumen
# Processing Record 9 of Set 7 | grindavik
# Processing Record 10 of Set 7 | knysna
# Processing Record 11 of Set 7 | shellbrook
# Processing Record 12 of Set 7 | touros
# Processing Record 13 of Set 7 | sola
# Processing Record 14 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 7 | mastic beach
# Processing Record 16 of Set 7 | nara
# Processing Record 17 of Set 7 | agucadoura
# Processing Record 18 of Set 7 | diapaga
# Processing Record 19 of Set 7 | qaqortoq
# Processing Record 20 of Set 7 | zhezkazgan
# Processing Record 21 of Set 7 | namwala
# Processing Record 22 of Set 7 | selikhino
# Processing Record 23 of Set 7 | buala
# Processing Record 24 of Set 7 | teresa
# Processing Record 25 of Set 7 | agnibilekrou
# Processing Record 26 of Set 7 | bathsheba
# Processing Record 27 of Set 7 | poum
# Processing Record 28 of Set 7 | namibe
# Processing Record 29 of Set 7 | lasa
# Processing Record 30 of Set 7 | nouna
# Processing Record 31 of Set 7 | foligno
# Processing Record 32 of Set 7 | wahpeton
# Processing Record 33 of Set 7 | juneau
# Processing Record 34 of Set 7 | tasiilaq
# Processing Record 35 of Set 7 | carnarvon
# Processing Record 36 of Set 7 | banda aceh
# Processing Record 37 of Set 7 | lagoa
# Processing Record 38 of Set 7 | konitsa
# Processing Record 39 of Set 7 | elat
# Processing Record 40 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 41 of Set 7 | najran
# Processing Record 42 of Set 7 | sterling
# Processing Record 43 of Set 7 | puerto carreno
# Processing Record 44 of Set 7 | san quintin
# Processing Record 45 of Set 7 | cabo san lucas
# Processing Record 46 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 47 of Set 7 | hay river
# Processing Record 48 of Set 7 | sur
# Processing Record 49 of Set 7 | fomboni
# Processing Record 50 of Set 7 | qabis
# City not found. Skipping...
# Processing Record 1 of Set 8 | laguna
# Processing Record 2 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 8 | cacule
# Processing Record 4 of Set 8 | kavaratti
# Processing Record 5 of Set 8 | tadine
# Processing Record 6 of Set 8 | concepcion del oro
# Processing Record 7 of Set 8 | caldwell
# Processing Record 8 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 9 of Set 8 | xianyang
# Processing Record 10 of Set 8 | ariquemes
# Processing Record 11 of Set 8 | inongo
# Processing Record 12 of Set 8 | patrasaer
# Processing Record 13 of Set 8 | havoysund
# Processing Record 14 of Set 8 | muros
# Processing Record 15 of Set 8 | potosi
# Processing Record 16 of Set 8 | whitefish
# Processing Record 17 of Set 8 | innisfail
# Processing Record 18 of Set 8 | acapulco
# Processing Record 19 of Set 8 | makakilo city
# Processing Record 20 of Set 8 | san carlos de bariloche
# Processing Record 21 of Set 8 | esperance
# Processing Record 22 of Set 8 | rapar
# Processing Record 23 of Set 8 | torbay
# Processing Record 24 of Set 8 | arica
# Processing Record 25 of Set 8 | morant bay
# Processing Record 26 of Set 8 | naze
# Processing Record 27 of Set 8 | ustyuzhna
# Processing Record 28 of Set 8 | kosice
# Processing Record 29 of Set 8 | dingle
# Processing Record 30 of Set 8 | narnaul
# Processing Record 31 of Set 8 | skjaerhollen
# City not found. Skipping...
# Processing Record 32 of Set 8 | racaciuni
# Processing Record 33 of Set 8 | montes altos
# Processing Record 34 of Set 8 | okato
# Processing Record 35 of Set 8 | tukan
# Processing Record 36 of Set 8 | traverse city
# Processing Record 37 of Set 8 | beatrice
# Processing Record 38 of Set 8 | finschhafen
# Processing Record 39 of Set 8 | caluquembe
# Processing Record 40 of Set 8 | klaksvik
# Processing Record 41 of Set 8 | biloela
# Processing Record 42 of Set 8 | souillac
# Processing Record 43 of Set 8 | chibombo
# Processing Record 44 of Set 8 | paamiut
# Processing Record 45 of Set 8 | flinders
# Processing Record 46 of Set 8 | kampot
# Processing Record 47 of Set 8 | sao joao da barra
# Processing Record 48 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 50 of Set 8 | aswan
# Processing Record 1 of Set 9 | marsaxlokk
# Processing Record 2 of Set 9 | billings
# Processing Record 3 of Set 9 | ketchikan
# Processing Record 4 of Set 9 | yorkton
# Processing Record 5 of Set 9 | aklavik
# Processing Record 6 of Set 9 | kieta
# Processing Record 7 of Set 9 | shaowu
# Processing Record 8 of Set 9 | pinheiro machado
# Processing Record 9 of Set 9 | tabou
# Processing Record 10 of Set 9 | vostok
# Processing Record 11 of Set 9 | saint-philippe
# Processing Record 12 of Set 9 | kaeo
# Processing Record 13 of Set 9 | fairbanks
# Processing Record 14 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 9 | bilibino
# Processing Record 16 of Set 9 | poso
# Processing Record 17 of Set 9 | ilulissat
# Processing Record 18 of Set 9 | tiksi
# Processing Record 19 of Set 9 | mananjary
# Processing Record 20 of Set 9 | leningradskiy
# Processing Record 21 of Set 9 | damaturu
# Processing Record 22 of Set 9 | kulim
# Processing Record 23 of Set 9 | pacific grove
# Processing Record 24 of Set 9 | omboue
# Processing Record 25 of Set 9 | stepnogorsk
# Processing Record 26 of Set 9 | teya
# Processing Record 27 of Set 9 | oron
# Processing Record 28 of Set 9 | shirokiy
# Processing Record 29 of Set 9 | diffa
# Processing Record 30 of Set 9 | malakal
# Processing Record 31 of Set 9 | clarence town
# Processing Record 32 of Set 9 | kenai
# Processing Record 33 of Set 9 | manjeshwar
# Processing Record 34 of Set 9 | winder
# Processing Record 35 of Set 9 | nova olimpia
# Processing Record 36 of Set 9 | coos bay
# Processing Record 37 of Set 9 | kaihua
# Processing Record 38 of Set 9 | havelock
# Processing Record 39 of Set 9 | port macquarie
# Processing Record 40 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 9 | miri
# Processing Record 42 of Set 9 | bagdarin
# Processing Record 43 of Set 9 | basco
# Processing Record 44 of Set 9 | soure
# Processing Record 45 of Set 9 | sieradz
# Processing Record 46 of Set 9 | ruwi
# Processing Record 47 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 9 | talcahuano
# Processing Record 49 of Set 9 | riyadh
# Processing Record 50 of Set 9 | vila franca do campo
# Processing Record 1 of Set 10 | homer
# Processing Record 2 of Set 10 | lakes entrance
# Processing Record 3 of Set 10 | herat
# Processing Record 4 of Set 10 | aberdeen
# Processing Record 5 of Set 10 | salamanca
# Processing Record 6 of Set 10 | derzhavinsk
# Processing Record 7 of Set 10 | padang
# Processing Record 8 of Set 10 | vila velha
# Processing Record 9 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 10 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 11 of Set 10 | trairi
# Processing Record 12 of Set 10 | goderich
# Processing Record 13 of Set 10 | grand gaube
# Processing Record 14 of Set 10 | margate
# Processing Record 15 of Set 10 | russell
# Processing Record 16 of Set 10 | richards bay
# Processing Record 17 of Set 10 | vao
# Processing Record 18 of Set 10 | guajara-mirim
# City not found. Skipping...
# Processing Record 19 of Set 10 | katherine
# Processing Record 20 of Set 10 | alofi
# Processing Record 21 of Set 10 | gitarama
# Processing Record 22 of Set 10 | barentu
# Processing Record 23 of Set 10 | khanpur
# Processing Record 24 of Set 10 | hasaki
# Processing Record 25 of Set 10 | evensk
# Processing Record 26 of Set 10 | powell
# Processing Record 27 of Set 10 | ulagan
# Processing Record 28 of Set 10 | nouadhibou
# Processing Record 29 of Set 10 | morros
# Processing Record 30 of Set 10 | ohara
# Processing Record 31 of Set 10 | comodoro rivadavia
# Processing Record 32 of Set 10 | bodden town
# Processing Record 33 of Set 10 | pilar
# Processing Record 34 of Set 10 | nikel
# Processing Record 35 of Set 10 | vardo
# Processing Record 36 of Set 10 | tutoia
# Processing Record 37 of Set 10 | uyemskiy
# Processing Record 38 of Set 10 | malanje
# Processing Record 39 of Set 10 | morro bay
# Processing Record 40 of Set 10 | taperoa
# Processing Record 41 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 10 | valguarnera caropepe
# Processing Record 43 of Set 10 | kashi
# Processing Record 44 of Set 10 | kungurtug
# Processing Record 45 of Set 10 | srednekolymsk
# Processing Record 46 of Set 10 | morehead
# Processing Record 47 of Set 10 | danielskuil
# Processing Record 48 of Set 10 | acarau
# Processing Record 49 of Set 10 | sapernoye
# Processing Record 50 of Set 10 | at-bashi
# Processing Record 1 of Set 11 | vammala
# Processing Record 2 of Set 11 | yen bai
# Processing Record 3 of Set 11 | sistranda
# Processing Record 4 of Set 11 | sivas
# Processing Record 5 of Set 11 | xuanzhou
# Processing Record 6 of Set 11 | beibei
# Processing Record 7 of Set 11 | turukhansk
# Processing Record 8 of Set 11 | half moon bay
# Processing Record 9 of Set 11 | roma
# Processing Record 10 of Set 11 | longyearbyen
# Processing Record 11 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 11 | finote selam
# Processing Record 13 of Set 11 | ambunti
# Processing Record 14 of Set 11 | rotnes
# Processing Record 15 of Set 11 | muktagachha
# City not found. Skipping...
# Processing Record 16 of Set 11 | ponta do sol
# Processing Record 17 of Set 11 | aramil
# Processing Record 18 of Set 11 | los llanos de aridane
# Processing Record 19 of Set 11 | tondano
# Processing Record 20 of Set 11 | birin
# Processing Record 21 of Set 11 | korla
# Processing Record 22 of Set 11 | virginia beach
# Processing Record 23 of Set 11 | merauke
# Processing Record 24 of Set 11 | caucaia
# Processing Record 25 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 11 | kupino
# Processing Record 27 of Set 11 | ardakan
# Processing Record 28 of Set 11 | idukki
# Processing Record 29 of Set 11 | outjo
# Processing Record 30 of Set 11 | mazara del vallo
# Processing Record 31 of Set 11 | lumphat
# Processing Record 32 of Set 11 | machali
# Processing Record 33 of Set 11 | omsukchan
# Processing Record 34 of Set 11 | datong
# Processing Record 35 of Set 11 | manduria
# Processing Record 36 of Set 11 | galveston
# Processing Record 37 of Set 11 | okhotsk
# Processing Record 38 of Set 11 | gerash
# Processing Record 39 of Set 11 | shache
# Processing Record 40 of Set 11 | manzhouli
# Processing Record 41 of Set 11 | panzhihua
# Processing Record 42 of Set 11 | mozarlandia
# Processing Record 43 of Set 11 | knyaze-volkonskoye
# Processing Record 44 of Set 11 | reutte
# Processing Record 45 of Set 11 | nome
# Processing Record 46 of Set 11 | kulhudhuffushi
# Processing Record 47 of Set 11 | oussouye
# Processing Record 48 of Set 11 | panixtlahuaca
# City not found. Skipping...
# Processing Record 49 of Set 11 | fort nelson
# Processing Record 50 of Set 11 | charters towers
# Processing Record 1 of Set 12 | vilshofen
# Processing Record 2 of Set 12 | san jose
# Processing Record 3 of Set 12 | burica
# City not found. Skipping...
# Processing Record 4 of Set 12 | westport
# Processing Record 5 of Set 12 | ibra
# Processing Record 6 of Set 12 | miramar
# Processing Record 7 of Set 12 | kollam
# Processing Record 8 of Set 12 | east wenatchee
# Processing Record 9 of Set 12 | maple creek
# Processing Record 10 of Set 12 | sug-aksy
# City not found. Skipping...
# Processing Record 11 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 12 | gonen
# Processing Record 13 of Set 12 | nam tha
# City not found. Skipping...
# Processing Record 14 of Set 12 | abong mbang
# Processing Record 15 of Set 12 | vila
# Processing Record 16 of Set 12 | verkh-usugli
# Processing Record 17 of Set 12 | xining
# Processing Record 18 of Set 12 | tucuma
# Processing Record 19 of Set 12 | dharchula
# Processing Record 20 of Set 12 | chemodanovka
# Processing Record 21 of Set 12 | karratha
# Processing Record 22 of Set 12 | santa quiteria
# Processing Record 23 of Set 12 | verkhnevilyuysk
# Processing Record 24 of Set 12 | hualmay
# Processing Record 25 of Set 12 | araouane
# Processing Record 26 of Set 12 | siniscola
# Processing Record 27 of Set 12 | blyth
# Processing Record 28 of Set 12 | batagay-alyta
# Processing Record 29 of Set 12 | christchurch
# Processing Record 30 of Set 12 | atambua
# Processing Record 31 of Set 12 | moron
# Processing Record 32 of Set 12 | kurtamysh
# Processing Record 33 of Set 12 | sept-iles
# Processing Record 34 of Set 12 | saravan
# Processing Record 35 of Set 12 | grand baie
# Processing Record 36 of Set 12 | puerto madryn
# Processing Record 37 of Set 12 | elban
# Processing Record 38 of Set 12 | taksimo
# Processing Record 39 of Set 12 | hit
# Processing Record 40 of Set 12 | husavik
# Processing Record 41 of Set 12 | mitu
# Processing Record 42 of Set 12 | malindi
# Processing Record 43 of Set 12 | ust-kulom
# Processing Record 44 of Set 12 | tanabe
# Processing Record 45 of Set 12 | lockhart
# Processing Record 46 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 47 of Set 12 | arrecife
# Processing Record 48 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 49 of Set 12 | dalby
# Processing Record 50 of Set 12 | gladstone
# Processing Record 1 of Set 13 | yanam
# Processing Record 2 of Set 13 | tocache
# Processing Record 3 of Set 13 | umm lajj
# Processing Record 4 of Set 13 | rawson
# Processing Record 5 of Set 13 | kutum
# Processing Record 6 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 13 | kainantu
# Processing Record 8 of Set 13 | msanga
# Processing Record 9 of Set 13 | bloemfontein
# Processing Record 10 of Set 13 | hilton head island
# Processing Record 11 of Set 13 | totma
# Processing Record 12 of Set 13 | cuamba
# Processing Record 13 of Set 13 | san felipe
# Processing Record 14 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 15 of Set 13 | batemans bay
# Processing Record 16 of Set 13 | sanchor
# Processing Record 17 of Set 13 | kathmandu
# Processing Record 18 of Set 13 | chumikan
# Processing Record 19 of Set 13 | krasnoselkup
# Processing Record 20 of Set 13 | nabire
# Processing Record 21 of Set 13 | pangai
# Processing Record 22 of Set 13 | uyuni
# Processing Record 23 of Set 13 | flin flon
# Processing Record 24 of Set 13 | darab
# Processing Record 25 of Set 13 | katobu
# Processing Record 26 of Set 13 | tazovskiy
# Processing Record 27 of Set 13 | cabedelo
# Processing Record 28 of Set 13 | sagar
# Processing Record 29 of Set 13 | chizhou
# Processing Record 30 of Set 13 | preobrazheniye
# Processing Record 31 of Set 13 | kamaishi
# Processing Record 32 of Set 13 | awjilah
# Processing Record 33 of Set 13 | gulbarga
# Processing Record 34 of Set 13 | sinjar
# Processing Record 35 of Set 13 | joensuu
# Processing Record 36 of Set 13 | matagami
# Processing Record 37 of Set 13 | bouna
# Processing Record 38 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 39 of Set 13 | bastia
# Processing Record 40 of Set 13 | bontang
# Processing Record 41 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 13 | portree
# Processing Record 43 of Set 13 | xingyi
# Processing Record 44 of Set 13 | buzmeyin
# Processing Record 45 of Set 13 | urusha
# Processing Record 46 of Set 13 | kudahuvadhoo
# Processing Record 47 of Set 13 | ekibastuz
# Processing Record 48 of Set 13 | sao filipe
# Processing Record 49 of Set 13 | zaysan
# Processing Record 50 of Set 13 | asarganj
# Processing Record 1 of Set 14 | kemijarvi
# Processing Record 2 of Set 14 | villiers
# Processing Record 3 of Set 14 | smithers
# Processing Record 4 of Set 14 | hun
# Processing Record 5 of Set 14 | kokopo
# Processing Record 6 of Set 14 | salinopolis
# Processing Record 7 of Set 14 | ayan
# Processing Record 8 of Set 14 | kiunga
# Processing Record 9 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 10 of Set 14 | saint-francois
# Processing Record 11 of Set 14 | kismayo
# Processing Record 12 of Set 14 | zhigansk
# Processing Record 13 of Set 14 | lagoa vermelha
# Processing Record 14 of Set 14 | asosa
# Processing Record 15 of Set 14 | gravdal
# Processing Record 16 of Set 14 | bonthe
# Processing Record 17 of Set 14 | yar-sale
# Processing Record 18 of Set 14 | vilyuysk
# Processing Record 19 of Set 14 | verkhoyansk
# Processing Record 20 of Set 14 | sioux lookout
# Processing Record 21 of Set 14 | ukiah
# Processing Record 22 of Set 14 | tarhunah
# City not found. Skipping...
# Processing Record 23 of Set 14 | agadez
# Processing Record 24 of Set 14 | santa maria
# Processing Record 25 of Set 14 | beisfjord
# Processing Record 26 of Set 14 | necochea
# Processing Record 27 of Set 14 | chicama
# Processing Record 28 of Set 14 | puerto colombia
# Processing Record 29 of Set 14 | uruacu
# Processing Record 30 of Set 14 | coahuayana
# Processing Record 31 of Set 14 | kyzyl-suu
# Processing Record 32 of Set 14 | hajduhadhaz
# Processing Record 33 of Set 14 | constitucion
# Processing Record 34 of Set 14 | ewa beach
# Processing Record 35 of Set 14 | taunton
# Processing Record 36 of Set 14 | brewster
# Processing Record 37 of Set 14 | saint-pierre
# Processing Record 38 of Set 14 | rocha
# Processing Record 39 of Set 14 | presidencia roque saenz pena
# Processing Record 40 of Set 14 | nusaybin
# Processing Record 41 of Set 14 | nyaunglebin
# Processing Record 42 of Set 14 | arman
# Processing Record 43 of Set 14 | bilma
# Processing Record 44 of Set 14 | non thai
# Processing Record 45 of Set 14 | piopio
# Processing Record 46 of Set 14 | viedma
# Processing Record 47 of Set 14 | xai-xai
# Processing Record 48 of Set 14 | kalmunai
# Processing Record 49 of Set 14 | partizanskoye
# Processing Record 50 of Set 14 | neryungri
# Processing Record 1 of Set 15 | martin
# Processing Record 2 of Set 15 | mariel
# Processing Record 3 of Set 15 | namatanai
# Processing Record 4 of Set 15 | udachnyy
# Processing Record 5 of Set 15 | birao
# Processing Record 6 of Set 15 | wad rawah
# Processing Record 7 of Set 15 | maine-soroa
# Processing Record 8 of Set 15 | la romana
# Processing Record 9 of Set 15 | caravelas
# Processing Record 10 of Set 15 | afmadu
# City not found. Skipping...
# Processing Record 11 of Set 15 | pitanga
# Processing Record 12 of Set 15 | tiznit
# Processing Record 13 of Set 15 | kondinskoye
# Processing Record 14 of Set 15 | warmbad
# Processing Record 15 of Set 15 | serov
# Processing Record 16 of Set 15 | mount gambier
# Processing Record 17 of Set 15 | conceicao do araguaia
# Processing Record 18 of Set 15 | bolobo
# Processing Record 19 of Set 15 | armizonskoye
# Processing Record 20 of Set 15 | hofn
# Processing Record 21 of Set 15 | nyurba
# Processing Record 22 of Set 15 | formosa do rio preto
# Processing Record 23 of Set 15 | nuuk
# Processing Record 24 of Set 15 | rajpipla
# Processing Record 25 of Set 15 | mandalgovi
# Processing Record 26 of Set 15 | mnogovershinnyy
# Processing Record 27 of Set 15 | yatou
# Processing Record 28 of Set 15 | fort dix
# Processing Record 29 of Set 15 | mao
# Processing Record 30 of Set 15 | slidell
# Processing Record 31 of Set 15 | quatre cocos
# Processing Record 32 of Set 15 | puerto palomas
# Processing Record 33 of Set 15 | pombas
# Processing Record 34 of Set 15 | kiskunhalas
# Processing Record 35 of Set 15 | atyrau
# Processing Record 36 of Set 15 | motygino
# Processing Record 37 of Set 15 | nicoya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 681

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Palmerston -12.4860  130.9833     91.89        67          40
# 1        Ushuaia -54.8000  -68.3000     38.86        81         100
# 2      Cape Town -33.9258   18.4232     69.39        73           0
# 3        Qaanaaq  77.4840  -69.3632    -20.16        64          25
# 4         Hobart -42.8794  147.3294     67.86        85         100
# ..           ...      ...       ...       ...       ...         ...
# 676       Pombas  17.1503  -25.0201     65.98        74          14
# 677  Kiskunhalas  46.4340   19.4848     34.59        84           3
# 678       Atyrau  47.1167   51.8833     30.22        93         100
# 679     Motygino  58.1831   94.7592    -14.01       100         100
# 680       Nicoya  10.1483  -85.4520     77.70        66           4
#
#      Wind Speed Country       Description
# 0         10.36      AU  scattered clouds
# 1         17.27      AR        light rain
# 2         14.00      ZA         clear sky
# 3          8.32      GL  scattered clouds
# 4         11.50      AU        light rain
# ..          ...     ...               ...
# 676       18.92      CV        few clouds
# 677        5.06      HU         clear sky
# 678       11.18      KZ       shower snow
# 679        1.45      RU   overcast clouds
# 680        9.13      CR         clear sky
#
# [681 rows x 9 columns]

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Palmerston -12.4860  130.9833     91.89        67          40       10.36
# 1      Ushuaia -54.8000  -68.3000     38.86        81         100       17.27
# 2    Cape Town -33.9258   18.4232     69.39        73           0       14.00
# 3      Qaanaaq  77.4840  -69.3632    -20.16        64          25        8.32
# 4       Hobart -42.8794  147.3294     67.86        85         100       11.50
# 5       Albany  42.6001  -73.9662     57.38        57           7        1.01
# 6       Atuona  -9.8000 -139.0333     78.84        73          62       13.15
# 7     Richmond  37.5538  -77.4603     65.05        54          40       11.50
# 8       Avarua -21.2078 -159.7750     86.05        74          63        5.75
# 9  Henties Bay -22.1160   14.2845     64.51        83          94        5.57
#
#   Country       Description
# 0      AU  scattered clouds
# 1      AR        light rain
# 2      ZA         clear sky
# 3      GL  scattered clouds
# 4      AU        light rain
# 5      US         clear sky
# 6      PF     broken clouds
# 7      US  scattered clouds
# 8      CK        light rain
# 9      NA   overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
new_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Description"]


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_order]

# Display sample data
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Palmerston      AU -12.4860  130.9833     91.89        67          40
# 1     Ushuaia      AR -54.8000  -68.3000     38.86        81         100
# 2   Cape Town      ZA -33.9258   18.4232     69.39        73           0
# 3     Qaanaaq      GL  77.4840  -69.3632    -20.16        64          25
# 4      Hobart      AU -42.8794  147.3294     67.86        85         100
#
#    Wind Speed       Description
# 0       10.36  scattered clouds
# 1       17.27        light rain
# 2       14.00         clear sky
# 3        8.32  scattered clouds
# 4       11.50        light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Create the output file (CSV).
output_data_file = 'weather_data/cities.csv'
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
